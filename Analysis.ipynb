# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter

# %%
def isdate(value):
    try:
        pd.to_datetime(value).date()
        return True
    except:
        return False
    
def isfloat(value):
    try:
        np.float64(value)
        return True
    except:
        return False
    
def isstring(value):
    try:
        str(value)
        return True
    except:
        return False
    
def isvalidname(value):
    try:
        return ' ' not in value
    except:
        return False

# %%
# Read in data, try to convert tweet_timestamp and created_at to timestamps
data = pd.read_csv('data.csv',error_bad_lines=False)

# Check whether tweet_timestamps are valid dates
data['is_date'] = data['tweet_timestamp'].apply(isdate)

# Subset data to only include rows where tweet_text contains valid string
data = data[data['tweet_text'].apply(isstring)]

# Subset data to only include valid dates
data = data[data['is_date']]

# Convert to valid timestamps
data['tweet_timestamp'] = pd.to_datetime(data['tweet_timestamp'],errors='raise',coerce=True,unit='s')

# Create date column for groupby functions later on
data['date'] = data['tweet_timestamp'].apply(lambda x:x.date())

# Limit data to valid dates in range
data = data[data['date'].isin([i.date() for i in pd.date_range('2014-10-21','2014-10-23')])]

data.head()
# Out:
# Skipping line 163: expected 19 fields, saw 21
# Skipping line 219: expected 19 fields, saw 20
# Skipping line 290: expected 19 fields, saw 20
# Skipping line 356: expected 19 fields, saw 21
# Skipping line 384: expected 19 fields, saw 20
# Skipping line 409: expected 19 fields, saw 20
# Skipping line 426: expected 19 fields, saw 20
# Skipping line 430: expected 19 fields, saw 21
# Skipping line 570: expected 19 fields, saw 20
# Skipping line 612: expected 19 fields, saw 20
# Skipping line 677: expected 19 fields, saw 20
# Skipping line 793: expected 19 fields, saw 20
# Skipping line 832: expected 19 fields, saw 20
# Skipping line 838: expected 19 fields, saw 20
# Skipping line 864: expected 19 fields, saw 20
# Skipping line 940: expected 19 fields, saw 20
# Skipping line 1244: expected 19 fields, saw 20
# Skipping line 1286: expected 19 fields, saw 21
# Skipping line 1337: expected 19 fields, saw 20
# Skipping line 1353: expected 19 fields, saw 20
# Skipping line 1375: expected 19 fields, saw 20
# Skipping line 1463: expected 19 fields, saw 20
# Skipping line 1557: expected 19 fields, saw 20
# Skipping line 1725: expected 19 fields, saw 20
# Skipping line 1797: expected 19 fields, saw 20
# Skipping line 1900: expected 19 fields, saw 20
# Skipping line 1952: expected 19 fields, saw 20
# Skipping line 1981: expected 19 fields, saw 20
# Skipping line 2051: expected 19 fields, saw 20
# Skipping line 2277: expected 19 fields, saw 20
# Skipping line 2461: expected 19 fields, saw 20
# Skipping line 2641: expected 19 fields, saw 20
# Skipping line 2664: expected 19 fields, saw 20
# Skipping line 2742: expected 19 fields, saw 20
# Skipping line 2918: expected 19 fields, saw 20
# Skipping line 2927: expected 19 fields, saw 20
# Skipping line 3357: expected 19 fields, saw 20
# Skipping line 3373: expected 19 fields, saw 20
# Skipping line 3449: expected 19 fields, saw 20
# Skipping line 3601: expected 19 fields, saw 20
# Skipping line 3659: expected 19 fields, saw 20
# Skipping line 3660: expected 19 fields, saw 20
# Skipping line 3720: expected 19 fields, saw 20
# Skipping line 3824: expected 19 fields, saw 20
# Skipping line 4015: expected 19 fields, saw 21
# Skipping line 4023: expected 19 fields, saw 20
# Skipping line 4031: expected 19 fields, saw 21
# Skipping line 4033: expected 19 fields, saw 21
# Skipping line 4038: expected 19 fields, saw 21
# Skipping line 4041: expected 19 fields, saw 21
# Skipping line 4043: expected 19 fields, saw 21
# Skipping line 4049: expected 19 fields, saw 21
# Skipping line 4053: expected 19 fields, saw 21
# Skipping line 4056: expected 19 fields, saw 21
# Skipping line 4059: expected 19 fields, saw 21
# Skipping line 4063: expected 19 fields, saw 21
# Skipping line 4065: expected 19 fields, saw 21
# Skipping line 4069: expected 19 fields, saw 21
# Skipping line 4073: expected 19 fields, saw 21
# Skipping line 4074: expected 19 fields, saw 21
# Skipping line 4076: expected 19 fields, saw 21
# Skipping line 4077: expected 19 fields, saw 21
# Skipping line 4087: expected 19 fields, saw 21
# Skipping line 4093: expected 19 fields, saw 21
# Skipping line 4096: expected 19 fields, saw 21
# Skipping line 4101: expected 19 fields, saw 21
# Skipping line 4106: expected 19 fields, saw 21
# Skipping line 4115: expected 19 fields, saw 21
# Skipping line 4123: expected 19 fields, saw 21
# Skipping line 4126: expected 19 fields, saw 21
# Skipping line 4151: expected 19 fields, saw 21
# Skipping line 4158: expected 19 fields, saw 21
# Skipping line 4167: expected 19 fields, saw 21
# Skipping line 4175: expected 19 fields, saw 21
# Skipping line 4202: expected 19 fields, saw 21
# Skipping line 4205: expected 19 fields, saw 21
# Skipping line 4250: expected 19 fields, saw 21
# Skipping line 4273: expected 19 fields, saw 21
# Skipping line 4274: expected 19 fields, saw 21
# Skipping line 4278: expected 19 fields, saw 21
# Skipping line 4280: expected 19 fields, saw 21
# Skipping line 4316: expected 19 fields, saw 21
# Skipping line 4326: expected 19 fields, saw 20
# Skipping line 4341: expected 19 fields, saw 21
# Skipping line 4347: expected 19 fields, saw 20
# Skipping line 4391: expected 19 fields, saw 20
# Skipping line 4401: expected 19 fields, saw 21
# Skipping line 4410: expected 19 fields, saw 21
# Skipping line 4447: expected 19 fields, saw 21
# Skipping line 4464: expected 19 fields, saw 20
# Skipping line 4465: expected 19 fields, saw 21
# Skipping line 4502: expected 19 fields, saw 20
# Skipping line 4563: expected 19 fields, saw 21
# Skipping line 4570: expected 19 fields, saw 21
# Skipping line 4598: expected 19 fields, saw 20
# Skipping line 4600: expected 19 fields, saw 20
# Skipping line 4617: expected 19 fields, saw 20
# Skipping line 4734: expected 19 fields, saw 21
# Skipping line 4753: expected 19 fields, saw 20
# Skipping line 4852: expected 19 fields, saw 20
# Skipping line 4857: expected 19 fields, saw 20
# Skipping line 4885: expected 19 fields, saw 21
# Skipping line 4895: expected 19 fields, saw 20
# Skipping line 4933: expected 19 fields, saw 21
# Skipping line 4967: expected 19 fields, saw 21
# Skipping line 4984: expected 19 fields, saw 21
# Skipping line 4991: expected 19 fields, saw 20
# Skipping line 4996: expected 19 fields, saw 21
# Skipping line 5011: expected 19 fields, saw 22
# Skipping line 5090: expected 19 fields, saw 21
# Skipping line 5092: expected 19 fields, saw 21
# Skipping line 5096: expected 19 fields, saw 21
# Skipping line 5136: expected 19 fields, saw 20
# Skipping line 5168: expected 19 fields, saw 21
# Skipping line 5175: expected 19 fields, saw 20
# Skipping line 5187: expected 19 fields, saw 20
# Skipping line 5229: expected 19 fields, saw 20
# Skipping line 5251: expected 19 fields, saw 21
# Skipping line 5303: expected 19 fields, saw 21
# Skipping line 5313: expected 19 fields, saw 21
# Skipping line 5315: expected 19 fields, saw 21
# Skipping line 5386: expected 19 fields, saw 21
# Skipping line 5527: expected 19 fields, saw 20
# Skipping line 5573: expected 19 fields, saw 20
# Skipping line 5627: expected 19 fields, saw 21
# Skipping line 5774: expected 19 fields, saw 20
# Skipping line 5861: expected 19 fields, saw 20
# Skipping line 5916: expected 19 fields, saw 20
# Skipping line 6029: expected 19 fields, saw 21
# Skipping line 6095: expected 19 fields, saw 20
# Skipping line 6126: expected 19 fields, saw 21
# Skipping line 6222: expected 19 fields, saw 20
# Skipping line 6246: expected 19 fields, saw 20
# Skipping line 6351: expected 19 fields, saw 20
# Skipping line 6413: expected 19 fields, saw 21
# Skipping line 6513: expected 19 fields, saw 21
# Skipping line 6699: expected 19 fields, saw 21
# Skipping line 6724: expected 19 fields, saw 20
# Skipping line 6784: expected 19 fields, saw 20
# Skipping line 6806: expected 19 fields, saw 21
# Skipping line 6832: expected 19 fields, saw 20
# Skipping line 6841: expected 19 fields, saw 21
# Skipping line 6964: expected 19 fields, saw 20
# Skipping line 6997: expected 19 fields, saw 22
# Skipping line 7038: expected 19 fields, saw 20
# Skipping line 7121: expected 19 fields, saw 20
# Skipping line 7175: expected 19 fields, saw 20
# Skipping line 7379: expected 19 fields, saw 21
# Skipping line 7398: expected 19 fields, saw 21
# Skipping line 7458: expected 19 fields, saw 20
# Skipping line 7530: expected 19 fields, saw 21
# Skipping line 7585: expected 19 fields, saw 20
# Skipping line 7603: expected 19 fields, saw 20
# Skipping line 7638: expected 19 fields, saw 20
# Skipping line 7685: expected 19 fields, saw 20
# Skipping line 7692: expected 19 fields, saw 20
# Skipping line 7695: expected 19 fields, saw 20
# Skipping line 7710: expected 19 fields, saw 20
# Skipping line 7714: expected 19 fields, saw 21
# Skipping line 7836: expected 19 fields, saw 21
# Skipping line 7837: expected 19 fields, saw 21
# Skipping line 7838: expected 19 fields, saw 20
# Skipping line 7903: expected 19 fields, saw 20
# Skipping line 7906: expected 19 fields, saw 20
# Skipping line 7990: expected 19 fields, saw 20
# Skipping line 8008: expected 19 fields, saw 20
# Skipping line 8047: expected 19 fields, saw 20
# Skipping line 8123: expected 19 fields, saw 21
# Skipping line 8139: expected 19 fields, saw 21
# Skipping line 8242: expected 19 fields, saw 20
# Skipping line 8244: expected 19 fields, saw 20
# Skipping line 8397: expected 19 fields, saw 20
# Skipping line 8424: expected 19 fields, saw 21
# Skipping line 8431: expected 19 fields, saw 20
# Skipping line 8732: expected 19 fields, saw 20
# Skipping line 8777: expected 19 fields, saw 20
# Skipping line 8819: expected 19 fields, saw 20
# Skipping line 8836: expected 19 fields, saw 21
# Skipping line 8844: expected 19 fields, saw 20
# Skipping line 9124: expected 19 fields, saw 21
# Skipping line 9218: expected 19 fields, saw 21
# Skipping line 9280: expected 19 fields, saw 20
# Skipping line 9382: expected 19 fields, saw 20
# Skipping line 9684: expected 19 fields, saw 20
# Skipping line 9761: expected 19 fields, saw 21
# Skipping line 9811: expected 19 fields, saw 21
# Skipping line 9839: expected 19 fields, saw 21
# Skipping line 9870: expected 19 fields, saw 20
# Skipping line 10019: expected 19 fields, saw 20
# Skipping line 10125: expected 19 fields, saw 21
# Skipping line 10134: expected 19 fields, saw 21
# Skipping line 10149: expected 19 fields, saw 20
# Skipping line 10208: expected 19 fields, saw 20
# Skipping line 10279: expected 19 fields, saw 20
# Skipping line 10281: expected 19 fields, saw 21
# Skipping line 10286: expected 19 fields, saw 20
# Skipping line 10341: expected 19 fields, saw 20
# Skipping line 10449: expected 19 fields, saw 20
# Skipping line 10469: expected 19 fields, saw 20
# Skipping line 10483: expected 19 fields, saw 20
# Skipping line 10484: expected 19 fields, saw 20
# Skipping line 10505: expected 19 fields, saw 20
# Skipping line 10507: expected 19 fields, saw 20
# Skipping line 10518: expected 19 fields, saw 20
# Skipping line 10574: expected 19 fields, saw 20
# Skipping line 10601: expected 19 fields, saw 20
# Skipping line 10708: expected 19 fields, saw 20
# Skipping line 10739: expected 19 fields, saw 20
# Skipping line 10764: expected 19 fields, saw 20
# Skipping line 10772: expected 19 fields, saw 21
# Skipping line 10773: expected 19 fields, saw 20
# Skipping line 10784: expected 19 fields, saw 20
# Skipping line 10820: expected 19 fields, saw 20
# Skipping line 10822: expected 19 fields, saw 20
# Skipping line 10823: expected 19 fields, saw 20
# Skipping line 10837: expected 19 fields, saw 20
# Skipping line 10899: expected 19 fields, saw 20
# Skipping line 10918: expected 19 fields, saw 21
# Skipping line 11023: expected 19 fields, saw 20
# Skipping line 11046: expected 19 fields, saw 20
# Skipping line 11067: expected 19 fields, saw 21
# Skipping line 11105: expected 19 fields, saw 20
# Skipping line 11171: expected 19 fields, saw 20
# Skipping line 11276: expected 19 fields, saw 20
# Skipping line 11293: expected 19 fields, saw 21
# Skipping line 11414: expected 19 fields, saw 20
# Skipping line 11445: expected 19 fields, saw 20
# Skipping line 11459: expected 19 fields, saw 20
# Skipping line 11547: expected 19 fields, saw 20
# Skipping line 11592: expected 19 fields, saw 20
# Skipping line 11593: expected 19 fields, saw 20
# Skipping line 11604: expected 19 fields, saw 20
# Skipping line 11669: expected 19 fields, saw 20
# Skipping line 11727: expected 19 fields, saw 20
# Skipping line 11799: expected 19 fields, saw 21
# Skipping line 11903: expected 19 fields, saw 20
# Skipping line 11932: expected 19 fields, saw 23
# Skipping line 11953: expected 19 fields, saw 20
# Skipping line 11954: expected 19 fields, saw 20
# Skipping line 12103: expected 19 fields, saw 20
# Skipping line 12119: expected 19 fields, saw 20
# Skipping line 12122: expected 19 fields, saw 20
# Skipping line 12139: expected 19 fields, saw 20
# Skipping line 17096: expected 19 fields, saw 21
# Skipping line 17182: expected 19 fields, saw 20
# Skipping line 17221: expected 19 fields, saw 21
# Skipping line 17225: expected 19 fields, saw 20
# Skipping line 17297: expected 19 fields, saw 20
# Skipping line 17300: expected 19 fields, saw 20
# Skipping line 17319: expected 19 fields, saw 21
# Skipping line 17324: expected 19 fields, saw 20
# Skipping line 17506: expected 19 fields, saw 20
# Skipping line 17563: expected 19 fields, saw 21
# Skipping line 17585: expected 19 fields, saw 20
# Skipping line 17708: expected 19 fields, saw 20
# Skipping line 17729: expected 19 fields, saw 21
# Skipping line 17848: expected 19 fields, saw 20
# Skipping line 17877: expected 19 fields, saw 20
# Skipping line 18030: expected 19 fields, saw 20
# Skipping line 18056: expected 19 fields, saw 20
# Skipping line 18065: expected 19 fields, saw 20
# Skipping line 18096: expected 19 fields, saw 20
# Skipping line 18168: expected 19 fields, saw 20
# Skipping line 18215: expected 19 fields, saw 20
# Skipping line 18224: expected 19 fields, saw 20
# Skipping line 18226: expected 19 fields, saw 20
# Skipping line 18266: expected 19 fields, saw 20
# Skipping line 18288: expected 19 fields, saw 20
# Skipping line 18296: expected 19 fields, saw 20
# Skipping line 18297: expected 19 fields, saw 20
# Skipping line 18393: expected 19 fields, saw 20
# Skipping line 18403: expected 19 fields, saw 20
# Skipping line 18426: expected 19 fields, saw 20
# Skipping line 18456: expected 19 fields, saw 21
# Skipping line 18503: expected 19 fields, saw 20
# Skipping line 18505: expected 19 fields, saw 20
# Skipping line 18544: expected 19 fields, saw 20
# Skipping line 18621: expected 19 fields, saw 20
# Skipping line 18639: expected 19 fields, saw 20
# Skipping line 18640: expected 19 fields, saw 20
# Skipping line 18691: expected 19 fields, saw 20
# Skipping line 18745: expected 19 fields, saw 20
# Skipping line 18782: expected 19 fields, saw 20
# Skipping line 18793: expected 19 fields, saw 20
# Skipping line 19102: expected 19 fields, saw 20
# Skipping line 19274: expected 19 fields, saw 20
# Skipping line 19455: expected 19 fields, saw 20
# Skipping line 19933: expected 19 fields, saw 20
# Skipping line 20065: expected 19 fields, saw 21
# Skipping line 20116: expected 19 fields, saw 20
# Skipping line 20194: expected 19 fields, saw 20
# Skipping line 20233: expected 19 fields, saw 21
# Skipping line 20243: expected 19 fields, saw 20
# Skipping line 20267: expected 19 fields, saw 21
# Skipping line 20311: expected 19 fields, saw 20
# Skipping line 20353: expected 19 fields, saw 20
# Skipping line 20414: expected 19 fields, saw 20
# Skipping line 20597: expected 19 fields, saw 20
# Skipping line 20723: expected 19 fields, saw 20
# Skipping line 20868: expected 19 fields, saw 20
# Skipping line 21020: expected 19 fields, saw 21
# Skipping line 21129: expected 19 fields, saw 21
# Skipping line 21135: expected 19 fields, saw 21
# Skipping line 21145: expected 19 fields, saw 20
# Skipping line 21239: expected 19 fields, saw 20
# Skipping line 21285: expected 19 fields, saw 20
# Skipping line 21288: expected 19 fields, saw 20
# Skipping line 21328: expected 19 fields, saw 20
# Skipping line 21333: expected 19 fields, saw 20
# Skipping line 21365: expected 19 fields, saw 20
# Skipping line 29145: expected 19 fields, saw 21
# Skipping line 29183: expected 19 fields, saw 20
# Skipping line 29207: expected 19 fields, saw 21
# Skipping line 29253: expected 19 fields, saw 20
# Skipping line 29255: expected 19 fields, saw 20
# Skipping line 29285: expected 19 fields, saw 20
# Skipping line 29316: expected 19 fields, saw 21
# Skipping line 29372: expected 19 fields, saw 20
# Skipping line 29379: expected 19 fields, saw 20
# Skipping line 29436: expected 19 fields, saw 21
# Skipping line 29462: expected 19 fields, saw 20
# Skipping line 29483: expected 19 fields, saw 20
# Skipping line 29501: expected 19 fields, saw 20
# Skipping line 29522: expected 19 fields, saw 20
# Skipping line 29542: expected 19 fields, saw 20
# Skipping line 29557: expected 19 fields, saw 20
# Skipping line 29616: expected 19 fields, saw 21
# Skipping line 29721: expected 19 fields, saw 20
# Skipping line 29752: expected 19 fields, saw 20
# Skipping line 29896: expected 19 fields, saw 20
# Skipping line 30091: expected 19 fields, saw 20
# Skipping line 30186: expected 19 fields, saw 20
# Skipping line 30222: expected 19 fields, saw 20
# Skipping line 30240: expected 19 fields, saw 20
# Skipping line 30282: expected 19 fields, saw 22
# Skipping line 30284: expected 19 fields, saw 20
# Skipping line 30393: expected 19 fields, saw 20
# Skipping line 30501: expected 19 fields, saw 21
# Skipping line 30757: expected 19 fields, saw 21
# Skipping line 30796: expected 19 fields, saw 20
# Skipping line 30936: expected 19 fields, saw 20
# Skipping line 30949: expected 19 fields, saw 20
# Skipping line 30974: expected 19 fields, saw 20
# Skipping line 31039: expected 19 fields, saw 21
# Skipping line 31067: expected 19 fields, saw 20
# Skipping line 31093: expected 19 fields, saw 20
# Skipping line 31100: expected 19 fields, saw 20
# Skipping line 31105: expected 19 fields, saw 20
# Skipping line 31133: expected 19 fields, saw 20
# Skipping line 31134: expected 19 fields, saw 20
# Skipping line 31143: expected 19 fields, saw 20
# Skipping line 31145: expected 19 fields, saw 20
# Skipping line 31215: expected 19 fields, saw 20
# Skipping line 31225: expected 19 fields, saw 20
# Skipping line 31240: expected 19 fields, saw 20
# Skipping line 31248: expected 19 fields, saw 20
# Skipping line 31265: expected 19 fields, saw 20
# Skipping line 31444: expected 19 fields, saw 20
# Skipping line 31584: expected 19 fields, saw 21
# Skipping line 31696: expected 19 fields, saw 21
# Skipping line 31705: expected 19 fields, saw 20
# Skipping line 31817: expected 19 fields, saw 20
# Skipping line 31840: expected 19 fields, saw 20
# Skipping line 31885: expected 19 fields, saw 20
# Skipping line 31900: expected 19 fields, saw 20
# Skipping line 31994: expected 19 fields, saw 20
# Skipping line 31995: expected 19 fields, saw 20
# Skipping line 32013: expected 19 fields, saw 20
# Skipping line 32084: expected 19 fields, saw 20
# Skipping line 32113: expected 19 fields, saw 20
# Skipping line 32151: expected 19 fields, saw 20
# Skipping line 32170: expected 19 fields, saw 20
# Skipping line 32192: expected 19 fields, saw 20
# Skipping line 32245: expected 19 fields, saw 20
# Skipping line 32349: expected 19 fields, saw 20
# Skipping line 32351: expected 19 fields, saw 21
# Skipping line 32425: expected 19 fields, saw 20
# Skipping line 35889: expected 19 fields, saw 24
# Skipping line 35890: expected 19 fields, saw 24
# Skipping line 35896: expected 19 fields, saw 24
# Skipping line 35905: expected 19 fields, saw 24
# Skipping line 35906: expected 19 fields, saw 20
# Skipping line 35907: expected 19 fields, saw 24
# Skipping line 35908: expected 19 fields, saw 24
# Skipping line 35911: expected 19 fields, saw 24
# Skipping line 35916: expected 19 fields, saw 24
# Skipping line 35917: expected 19 fields, saw 24
# Skipping line 35927: expected 19 fields, saw 20
# Skipping line 35944: expected 19 fields, saw 21
# Skipping line 35975: expected 19 fields, saw 24
# Skipping line 35976: expected 19 fields, saw 24
# Skipping line 35979: expected 19 fields, saw 24
# Skipping line 35983: expected 19 fields, saw 24
# Skipping line 35985: expected 19 fields, saw 24
# Skipping line 35987: expected 19 fields, saw 24
# Skipping line 35988: expected 19 fields, saw 24
# Skipping line 36010: expected 19 fields, saw 20
# Skipping line 36013: expected 19 fields, saw 24
# Skipping line 36022: expected 19 fields, saw 24
# Skipping line 36023: expected 19 fields, saw 24
# Skipping line 36037: expected 19 fields, saw 24
# Skipping line 36051: expected 19 fields, saw 20
# Skipping line 36060: expected 19 fields, saw 24
# Skipping line 36062: expected 19 fields, saw 24
# Skipping line 36068: expected 19 fields, saw 24
# Skipping line 36073: expected 19 fields, saw 24
# Skipping line 36080: expected 19 fields, saw 24
# Skipping line 36082: expected 19 fields, saw 24
# Skipping line 36090: expected 19 fields, saw 20
# Skipping line 36101: expected 19 fields, saw 20
# Skipping line 36124: expected 19 fields, saw 24
# Skipping line 36137: expected 19 fields, saw 24
# Skipping line 36145: expected 19 fields, saw 24
# Skipping line 36151: expected 19 fields, saw 24
# Skipping line 36163: expected 19 fields, saw 24
# Skipping line 36178: expected 19 fields, saw 24
# Skipping line 36206: expected 19 fields, saw 24
# Skipping line 36208: expected 19 fields, saw 24
# Skipping line 36262: expected 19 fields, saw 24
# Skipping line 36271: expected 19 fields, saw 24
# Skipping line 36280: expected 19 fields, saw 20
# Skipping line 36281: expected 19 fields, saw 24
# Skipping line 36286: expected 19 fields, saw 20
# Skipping line 36287: expected 19 fields, saw 24
# Skipping line 36293: expected 19 fields, saw 24
# Skipping line 36337: expected 19 fields, saw 21
# Skipping line 36348: expected 19 fields, saw 21
# Skipping line 36390: expected 19 fields, saw 24
# Skipping line 36391: expected 19 fields, saw 24
# Skipping line 36415: expected 19 fields, saw 24
# Skipping line 36434: expected 19 fields, saw 20
# Skipping line 36453: expected 19 fields, saw 24
# Skipping line 36481: expected 19 fields, saw 24
# Skipping line 36493: expected 19 fields, saw 20
# Skipping line 36494: expected 19 fields, saw 24
# Skipping line 36498: expected 19 fields, saw 20
# Skipping line 36550: expected 19 fields, saw 20
# Skipping line 36572: expected 19 fields, saw 20
# Skipping line 36575: expected 19 fields, saw 24
# Skipping line 36584: expected 19 fields, saw 24
# Skipping line 36589: expected 19 fields, saw 24
# Skipping line 36600: expected 19 fields, saw 24
# Skipping line 36611: expected 19 fields, saw 24
# Skipping line 36636: expected 19 fields, saw 21
# Skipping line 39403: expected 19 fields, saw 24
# Skipping line 39412: expected 19 fields, saw 24
# Skipping line 39503: expected 19 fields, saw 24
# Skipping line 39528: expected 19 fields, saw 24
# Skipping line 39549: expected 19 fields, saw 20
# Skipping line 39603: expected 19 fields, saw 21
# Skipping line 39789: expected 19 fields, saw 24
# Skipping line 39839: expected 19 fields, saw 20
# Skipping line 39848: expected 19 fields, saw 21
# Skipping line 39859: expected 19 fields, saw 20
# Skipping line 39881: expected 19 fields, saw 21
# Skipping line 39979: expected 19 fields, saw 20
# Skipping line 40012: expected 19 fields, saw 20
# Skipping line 40073: expected 19 fields, saw 24
# Skipping line 40208: expected 19 fields, saw 24
# Skipping line 40291: expected 19 fields, saw 20
# Skipping line 40325: expected 19 fields, saw 24
# Skipping line 40347: expected 19 fields, saw 20
# Skipping line 40437: expected 19 fields, saw 24
# Skipping line 40444: expected 19 fields, saw 20
# Skipping line 40448: expected 19 fields, saw 20
# Skipping line 40461: expected 19 fields, saw 21
# Skipping line 40519: expected 19 fields, saw 24
# Skipping line 40564: expected 19 fields, saw 20
# Skipping line 40611: expected 19 fields, saw 20
# Skipping line 40640: expected 19 fields, saw 21
# Skipping line 40646: expected 19 fields, saw 24
# Skipping line 40721: expected 19 fields, saw 24
# Skipping line 40782: expected 19 fields, saw 24
# Skipping line 40786: expected 19 fields, saw 20
# Skipping line 40807: expected 19 fields, saw 24
# Skipping line 40848: expected 19 fields, saw 20
# Skipping line 40945: expected 19 fields, saw 24
# Skipping line 41019: expected 19 fields, saw 24
# Skipping line 41169: expected 19 fields, saw 20
# Skipping line 41363: expected 19 fields, saw 21
# Skipping line 41388: expected 19 fields, saw 24
# Skipping line 41528: expected 19 fields, saw 20
# Skipping line 41546: expected 19 fields, saw 20
# Skipping line 41690: expected 19 fields, saw 20
# Skipping line 41714: expected 19 fields, saw 21
# Skipping line 41732: expected 19 fields, saw 20
# Skipping line 41733: expected 19 fields, saw 20
# Skipping line 41736: expected 19 fields, saw 20
# Skipping line 41743: expected 19 fields, saw 20
# Skipping line 41744: expected 19 fields, saw 20
# Skipping line 41745: expected 19 fields, saw 20
# Skipping line 41746: expected 19 fields, saw 20
# Skipping line 41748: expected 19 fields, saw 20
# Skipping line 41752: expected 19 fields, saw 20
# Skipping line 41753: expected 19 fields, saw 20
# Skipping line 41759: expected 19 fields, saw 20
# Skipping line 41763: expected 19 fields, saw 20
# Skipping line 41764: expected 19 fields, saw 20
# Skipping line 41765: expected 19 fields, saw 20
# Skipping line 41772: expected 19 fields, saw 20
# Skipping line 41780: expected 19 fields, saw 20
# Skipping line 41782: expected 19 fields, saw 20
# Skipping line 41783: expected 19 fields, saw 20
# Skipping line 41787: expected 19 fields, saw 20
# Skipping line 41789: expected 19 fields, saw 20
# Skipping line 41793: expected 19 fields, saw 20
# Skipping line 41797: expected 19 fields, saw 20
# Skipping line 41799: expected 19 fields, saw 20
# Skipping line 41801: expected 19 fields, saw 20
# Skipping line 41803: expected 19 fields, saw 20
# Skipping line 41805: expected 19 fields, saw 20
# Skipping line 337096: expected 19 fields, saw 20
# Skipping line 337137: expected 19 fields, saw 20
# Skipping line 337176: expected 19 fields, saw 21
# Skipping line 337199: expected 19 fields, saw 21
# Skipping line 337224: expected 19 fields, saw 20
# Skipping line 337240: expected 19 fields, saw 20
# Skipping line 337255: expected 19 fields, saw 20
# Skipping line 337269: expected 19 fields, saw 20
# Skipping line 337313: expected 19 fields, saw 20
# Skipping line 337331: expected 19 fields, saw 20
# Skipping line 337361: expected 19 fields, saw 21
# Skipping line 337374: expected 19 fields, saw 20
# Skipping line 337409: expected 19 fields, saw 21
# Skipping line 337423: expected 19 fields, saw 20
# Skipping line 337425: expected 19 fields, saw 20
# Skipping line 337434: expected 19 fields, saw 20
# Skipping line 337527: expected 19 fields, saw 20
# Skipping line 337582: expected 19 fields, saw 21
# Skipping line 337633: expected 19 fields, saw 20
# Skipping line 337844: expected 19 fields, saw 22
# /Users/brianckeegan/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1139: DtypeWarning: Columns (1,9,11,14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#       id            tweet_id     tweet_timestamp  \
# 0  91794  524349343353294848 2014-10-21 00:00:00
# 1  91795  524349351259566080 2014-10-21 00:00:01
# 2  91796  524349355528945664 2014-10-21 00:00:02
# 3  91797  524349359601635329 2014-10-21 00:00:03
# 4  91798  524349361074212864 2014-10-21 00:00:04
#
#                                           tweet_text     user_id  \
# 0  @waxpancake \n#GamerGate\n#TheFireRises http:/...  1464599533
# 1  RT @CHSommers: #GamerGate is diverse.Lots of l...  1435309448
# 2  Think you're tired of #GamerGate? Imagine what...    19932466
# 3  RT @Toshi_TNE: #GamerGate Show them how tired ...   940132086
# 4  Charlie Brookers article on #GamerGate was poo...  1945343251
#
#              user_name user_screen_name  \
# 0           Fox Mulder      FoxAndAHalf
# 1    Hecarim Van Hohen  HecarimVanHohen
# 2  JamiEEEEEEEK! Wyman      BeeGirlBlue
# 3           HisShadowX       HisShadowX
# 4       Andrew Forrest        okforrest
#
#                                     user_description      user_created_at  \
# 0  Leader of #GamerGate with the best hair. You c...  2013-05-28 12:41:28
# 1                                                NaN  2013-05-17 10:39:19
# 2  Author of WILD CARD (2013), UNVEILED (11/2014)...  2009-02-02 21:08:05
# 3                                                NaN  2012-11-10 23:12:13
# 4  City ________ . Part-time photographer. Full-t...  2013-10-07 22:36:01
#
#   user_default_profile         ...           user_followers_count  \
# 0                    0         ...                            165
# 1                    0         ...                             12
# 2                    0         ...                            791
# 3                    1         ...                             26
# 4                    0         ...                             21
#
#   user_friends_count  user_statuses_count  retweeted_tweet_id  \
# 0                145                 3018                 NaN
# 1                 18                   34  524348019148591104
# 2                426                28976                 NaN
# 3                 42                  825  524345789498544129
# 4                127                  385                 NaN
#
#   retweeted_user_id retweeted_user_screen_name retweeted_count  \
# 0               NaN                        NaN             NaN
# 1         334921581                  CHSommers              88
# 2               NaN                        NaN             NaN
# 3         159708757                  Toshi_TNE              55
# 4               NaN                        NaN             NaN
#
#             created_at is_date        date
# 0  2014-10-20 19:00:00    True  2014-10-21
# 1  2014-10-20 19:00:02    True  2014-10-21
# 2  2014-10-20 19:00:03    True  2014-10-21
# 3  2014-10-20 19:00:04    True  2014-10-21
# 4  2014-10-20 19:00:04    True  2014-10-21
#
# [5 rows x 21 columns]

# %% [markdown]
# # Data cleanup and groupbys

# %%
# Subset data to only include retweets
rt_data = data.dropna(subset=['retweeted_user_screen_name'])

# Subset data to remove non-float-able values, convert remainder to floats
rt_data = rt_data[rt_data['retweeted_count'].apply(isfloat)]
rt_data['retweeted_count'] = rt_data['retweeted_count'].apply(np.float64)

# Groupby user_name and retweeted_username that will become edgelist
rt_gb = rt_data.groupby(['user_screen_name','retweeted_user_screen_name'])

# Create rt_agg DataFrame with aggregate statistics for each edge
rt_agg = rt_gb.agg({'tweet_timestamp':{'ts_min':min,'ts_max':max},
                    'tweet_id':{'weight':len},
                    'retweeted_count':{'rt_max':max,'rt_min':min,'rt_sum':np.sum}
                    })
rt_agg.columns = rt_agg.columns.droplevel(0)

# Include only edges with >1 RT
rt_agg = rt_agg[rt_agg['weight'] > 1]

# Data cleanup
rt_agg['ts_min'] = (rt_agg['ts_min'] - pd.Timestamp('2014-10-21'))/np.timedelta64(1,'D')
rt_agg['ts_max'] = (rt_agg['ts_max'] - pd.Timestamp('2014-10-21'))/np.timedelta64(1,'D')
rt_agg['rt_fraction'] = rt_agg['weight']/rt_agg['rt_sum']
rt_agg.head()
# Out:
#                                              weight  rt_min  rt_sum  rt_max  \
# user_screen_name retweeted_user_screen_name
# 007Bistromath    Chriss_m                         3       1     377     282
# 00Hex            ChrisWarcraft                    3       3      67      35
# 00looper00       BeninCitizen                     4       2     136     129
#                  srhbutts                         2      11      36      25
# 0_chainz_haver   MomsAgainstGam                   2      32     103      71
#
#                                                ts_min    ts_max  rt_fraction
# user_screen_name retweeted_user_screen_name
# 007Bistromath    Chriss_m                    1.399977  2.218900     0.007958
# 00Hex            ChrisWarcraft               2.058183  2.069456     0.044776
# 00looper00       BeninCitizen                2.541701  2.557431     0.029412
#                  srhbutts                    2.359757  2.543981     0.055556
# 0_chainz_haver   MomsAgainstGam              0.962546  1.052257     0.019417

# %%
# Subset data to only include tweets for users in graph
tweeters = data[data['user_screen_name'].isin(rt_agg.reset_index()['user_screen_name'].values)]
retweeters = data[data['user_screen_name'].isin(rt_agg.reset_index()['retweeted_user_screen_name'].values)]
g_data = pd.concat([tweeters,retweeters])

# Remove rows where account creation date is not valid
g_data = g_data[g_data['user_created_at'].apply(isdate)]
g_data['user_created_at'] = g_data['user_created_at'].apply(pd.Timestamp)

# Remove rows where other counts are not valid
g_data = g_data[g_data['user_followers_count'].apply(isfloat)]
g_data['user_followers_count'] = g_data['user_followers_count'].apply(np.float64)

g_data = g_data[g_data['user_friends_count'].apply(isfloat)]
g_data['user_friends_count'] = g_data['user_friends_count'].apply(np.float64)

g_data = g_data[g_data['user_statuses_count'].apply(isfloat)]
g_data['user_statuses_count'] = g_data['user_statuses_count'].apply(np.float64)

# Group by user_screen_name to create nodelist
g_gb = g_data.groupby('user_screen_name')

# Create agggregated DataFrame of all users tweets and summary statistics
g_agg = g_gb.agg({'tweet_id':{'tweets':len},
                  'user_followers_count':{'followers_min':min,'followers_max':max},
                  'user_friends_count':{'followees_min':min,'followees_max':max},
                  'user_statuses_count':{'statuses_min':min,'statuses_max':max},
                  'user_created_at':{'account_age':min}})
g_agg.columns = g_agg.columns.droplevel(0)

g_agg['account_age'] = (pd.Timestamp('2014-10-24') - g_agg['account_age'])/np.timedelta64(1,'D')
g_agg['tweets_delta'] = g_agg['statuses_max'] - g_agg['statuses_min']
g_agg['followers_delta'] = g_agg['followers_max'] - g_agg['followers_min']
g_agg['followees_delta'] = g_agg['followees_max'] - g_agg['followees_min']
g_agg['tweet_intensity'] = g_agg['tweets']/(g_agg['tweets_delta']+1)
g_agg['tweet_fraction'] = g_agg['tweets']/g_agg['statuses_min']

g_agg.sort('tweets',ascending=False).head()
# Out:
#                   tweets  statuses_max  statuses_min  followers_min  \
# user_screen_name
# SomeKindaBoogin     4592         25500         22819            758
# b00nes              2322          1991             4             59
# dav_thwomp          1880          4812          3543             61
# ArtAndFreedom       1774          4926          3640              0
# Bananaramble        1708          3779          1396             44
#
#                   followers_max  account_age  followees_max  followees_min  \
# user_screen_name
# SomeKindaBoogin             801    48.826238            842            819
# b00nes                       87  1846.480289              7              0
# dav_thwomp                   74   632.144884             38             36
# ArtAndFreedom               534    16.027604            692              0
# Bananaramble                113     7.924375            235            172
#
#                   tweets_delta  followers_delta  followees_delta  \
# user_screen_name
# SomeKindaBoogin           2681               43               23
# b00nes                    1987               28                7
# dav_thwomp                1269               13                2
# ArtAndFreedom             1286              534              692
# Bananaramble              2383               69               63
#
#                   tweet_intensity  tweet_fraction
# user_screen_name
# SomeKindaBoogin          1.712155        0.201236
# b00nes                   1.168008      580.500000
# dav_thwomp               1.480315        0.530624
# ArtAndFreedom            1.378399        0.487363
# Bananaramble             0.716443        1.223496

# %%
g_agg.to_csv('rt_graph_nodelist.csv',encoding='utf8')
rt_agg.to_csv('rt_graph_edgelist.csv',encoding='utf8')

# %% [markdown]
# # Create a network

# %%
g = nx.DiGraph()

for i,r in rt_agg.reset_index().iterrows():
    g.add_edge(r['user_screen_name'],r['retweeted_user_screen_name'],
               {k:float(v) for k,v in dict(rt_agg.ix[r['user_screen_name']].ix[r['retweeted_user_screen_name']]).items()})
    
for i,r in g_agg.reset_index().iterrows():
    g.add_node(r['user_screen_name'],
               {k:float(v) for k,v in dict(g_agg.ix[r['user_screen_name']]).items()})

# %%
len(g)
# Out:
# 5498

# %%
nx.write_gexf(g,'retweet_graph_gt1.gexf')

# %% [markdown]
# # Mentions and Hashtags

# %%
def regex_matcher(pattern,string):
    try:
        results = re.findall(pattern,string)
        if len(results) > 0:
            return [i.lower() for i in results]
        else:
            return np.nan
    except TypeError:
        return np.nan
    
def reciprocity(graph):
    d = dict()
    for n in graph.nodes_iter():
        s = set(graph.successors(n))
        p = set(graph.predecessors(n))
        if len(s | p) > 0:
            r = len(s & p)/float(len(s | p))
        else:
            r = 0
        d[n] = r
    return d
    
# From http://stackoverflow.com/a/6351873/1574687
_m = r'(?<=^|(?<=[^a-zA-Z0-9-_\.]))@([A-Za-z_]+[A-Za-z0-9_]+)'
_h = r'(?<=^|(?<=[^a-zA-Z0-9-_\.]))#([A-Za-z_]+[A-Za-z0-9_]+)'

# Create list of mentions for each tweet
data['mentions'] = data['tweet_text'].map(lambda x:regex_matcher(_m,x))
data['hashtags'] = data['tweet_text'].map(lambda x:regex_matcher(_h,x))

# %% [markdown]
# ### Mentions

# %%
mentions_data = data.dropna(subset=['mentions'])
print len(mentions_data)
mentions_data = mentions_data[mentions_data['user_screen_name'].apply(isvalidname)]
print len(mentions_data)
# Out:
# 260160
# 252352

# %%
mentions_g = nx.DiGraph()

for i,r in mentions_data.iterrows():
    for u in r['mentions']:
        s = r['user_screen_name'].lower()
        t = u.lower()
        try: 
            mentions_g[s][t]['weight'] += 1
        except KeyError:
            mentions_g.add_edge(s,t,weight=1)

# %%
mg_size = len(mentions_g)

mg_df = pd.DataFrame()
mg_df['odc'] = pd.Series({k:int(v*(mg_size-1)) for k,v in nx.out_degree_centrality(mentions_g).iteritems()})
mg_df['idc'] = pd.Series({k:int(v*(mg_size-1)) for k,v in nx.in_degree_centrality(mentions_g).iteritems()})
mg_df['cc'] = pd.Series(nx.clustering(mentions_g.to_undirected()))
mg_df['reciprocity'] = pd.Series(reciprocity(mentions_g))
mg_df['diff'] = (mg_df['idc'] - mg_df['odc'])/(mg_df['idc'] + mg_df['odc'])

mg_df.sort(columns='cc',ascending=False).head(10)
# Out:
#                  odc  idc  cc  reciprocity      diff
# guitarslingingm    2    0   1            0 -1.000000
# liqweed            2    0   1            0 -1.000000
# littlemousling     2    0   1            0 -1.000000
# lithiumproject     2    0   1            0 -1.000000
# egrant23           2    1   1            0 -0.333333
# skeleton2spooky    2    0   1            0 -1.000000
# lissidawn          2    0   1            0 -1.000000
# skepdirt           3    0   1            0 -1.000000
# lisakbromley       2    0   1            0 -1.000000
# bloodmediocrity    3    0   1            0 -1.000000

# %%
# Remove rows where account creation date is not valid
mentions_data = mentions_data[mentions_data['user_created_at'].apply(isdate)]
mentions_data['user_created_at'] = mentions_data['user_created_at'].apply(pd.Timestamp)

# Remove rows where other counts are not valid
mentions_data = mentions_data[mentions_data['user_followers_count'].apply(isfloat)]
mentions_data['user_followers_count'] = mentions_data['user_followers_count'].apply(np.float64)

mentions_data = mentions_data[mentions_data['user_friends_count'].apply(isfloat)]
mentions_data['user_friends_count'] = mentions_data['user_friends_count'].apply(np.float64)

mentions_data = mentions_data[mentions_data['user_statuses_count'].apply(isfloat)]
mentions_data['user_statuses_count'] = mentions_data['user_statuses_count'].apply(np.float64)

# Group by user_screen_name to create nodelist
mentions_gb = mentions_data.groupby('user_screen_name')

# Create agggregated DataFrame of all users tweets and summary statistics
mentions_agg = mentions_gb.agg({'tweet_id':{'tweets':len},
                  'user_followers_count':{'followers_min':min,'followers_max':max},
                  'user_friends_count':{'followees_min':min,'followees_max':max},
                  'user_statuses_count':{'statuses_min':min,'statuses_max':max},
                  'user_created_at':{'account_age':min}})
mentions_agg.columns = mentions_agg.columns.droplevel(0)

mentions_agg['account_age'] = (pd.Timestamp('2014-10-24') - mentions_agg['account_age'])/np.timedelta64(1,'D')
mentions_agg['tweets_delta'] = mentions_agg['statuses_max'] - mentions_agg['statuses_min']
mentions_agg['followers_delta'] = mentions_agg['followers_max'] - mentions_agg['followers_min']
mentions_agg['followees_delta'] = mentions_agg['followees_max'] - mentions_agg['followees_min']
mentions_agg['tweet_intensity'] = (mentions_agg['tweets']+1)/(mentions_agg['tweets_delta']+1)
mentions_agg['tweet_fraction'] = mentions_agg['tweets']/mentions_agg['statuses_min']

# Lowercase usernames for future joinabilitiy
mentions_agg.index = mentions_agg.reset_index()['user_screen_name'].apply(lambda x:x.lower())

# %%
mentions = mentions_agg.join(mg_df)
#mentions = mentions.reset_index()
mentions.head()
# Out:
#                tweets  statuses_max  statuses_min  followers_min  \
# 007bistromath      27           868           721             15
# 0080f0              1           133           133             11
# 00_gram             1          5475          5475             50
# 00hex               3        120141        120135            770
# 00looper00         11          1586          1471             39
#
#                followers_max  account_age  followees_max  followees_min  \
# 007bistromath             16   163.008981             11             10
# 0080f0                    11   143.220185             10             10
# 00_gram                   50  1725.774132            234            234
# 00hex                    770  2307.722049           1255           1255
# 00looper00                40  2065.021701            350            342
#
#                tweets_delta  followers_delta  followees_delta  \
# 007bistromath           147                1                1
# 0080f0                    0                0                0
# 00_gram                   0                0                0
# 00hex                     6                0                0
# 00looper00              115                1                8
#
#                tweet_intensity  tweet_fraction  odc  idc        cc  \
# 007bistromath         0.189189        0.037448   28    0  0.164021
# 0080f0                2.000000        0.007519    3    0  1.000000
# 00_gram               2.000000        0.000183    1    0  0.000000
# 00hex                 0.571429        0.000025    3    0  0.666667
# 00looper00            0.103448        0.007478   11    0  0.272727
#
#                reciprocity  diff
# 007bistromath            0    -1
# 0080f0                   0    -1
# 00_gram                  0    -1
# 00hex                    0    -1
# 00looper00               0    -1

# %%
for n in mentions_g.nodes_iter():
    try:
        # There is some bizzare bug in the aggregate function that is returning DataFrames instead of Series
        if n in mentions.index.values and type(mentions_agg.ix[n]) == pd.core.frame.Series:
            try:
                mentions_g.add_node(n,{k:float(v) for k,v in dict(mentions.ix[n]).items()})
            except TypeError:
                print n
    except KeyError:
        pass

nx.write_gexf(mentions_g,'mentions_graph.gexf')

# %% [markdown]
# ### Hashtags

# %%
hashtags_data = data.dropna(subset=['hashtags'])[['user_screen_name','hashtags']]
print len(hashtags_data)
hashtags_data = hashtags_data[hashtags_data['user_screen_name'].apply(isvalidname)]
print len(hashtags_data)
# Out:
# 277837
# 274819

# %%
hashtags_g = nx.DiGraph()

for i,r in hashtags_data.iterrows():
    for h in r['hashtags']:
        _h = h.lower()
        _u = [r['user_screen_name'].lower()
        if _h != 'gamergate':
            try: 
                hashtags_g[_u]][_h]['weight'] += 1
            except KeyError:
                hashtags_g.add_edge(_u,_h,weight=1)
        hashtags_g.add_node(_u,kind='user')
        hashtags_g.add_node(_h,kind='hashtag')
# Out:
#   File "<ipython-input-20-9e10836fe9dc>", line 7
#     if _h != 'gamergate':
#                         ^
# SyntaxError: invalid syntax

# %%
hg_size = len(mentions_g)

hg_df = pd.DataFrame()
hg_df['odc'] = pd.Series({k:int(v*(hg_size-1)) for k,v in nx.out_degree_centrality(mentions_g).iteritems()})
hg_df['idc'] = pd.Series({k:int(v*(hg_size-1)) for k,v in nx.in_degree_centrality(mentions_g).iteritems()})
hg_df['cc'] = pd.Series(nx.clustering(mentions_g.to_undirected()))
hg_df['reciprocity'] = pd.Series(reciprocity(mentions_g))
hg_df['diff'] = (hg_df['idc'] - hg_df['odc'])/(hg_df['idc'] + hg_df['odc'])

# %%
# Remove rows where account creation date is not valid
hashtags_data = hashtags_data[hashtags_data['user_created_at'].apply(isdate)]
hashtags_data['user_created_at'] = hashtags_data['user_created_at'].apply(pd.Timestamp)

# Remove rows where other counts are not valid
hashtags_data = hashtags_data[hashtags_data['user_followers_count'].apply(isfloat)]
hashtags_data['user_followers_count'] = hashtags_data['user_followers_count'].apply(np.float64)

hashtags_data = hashtags_data[hashtags_data['user_friends_count'].apply(isfloat)]
hashtags_data['user_friends_count'] = hashtags_data['user_friends_count'].apply(np.float64)

hashtags_data = hashtags_data[hashtags_data['user_statuses_count'].apply(isfloat)]
hashtags_data['user_statuses_count'] = hashtags_data['user_statuses_count'].apply(np.float64)

# Group by user_screen_name to create nodelist
hashtags_gb = hashtags_data.groupby('user_screen_name')

# Create agggregated DataFrame of all users tweets and summary statistics
hashtags_agg = hashtags_gb.agg({'tweet_id':{'tweets':len},
                  'user_followers_count':{'followers_min':min,'followers_max':max},
                  'user_friends_count':{'followees_min':min,'followees_max':max},
                  'user_statuses_count':{'statuses_min':min,'statuses_max':max},
                  'user_created_at':{'account_age':min}})
hashtags_agg.columns = hashtags_agg.columns.droplevel(0)

hashtags_agg['account_age'] = (pd.Timestamp('2014-10-24') - hashtags_agg['account_age'])/np.timedelta64(1,'D')
hashtags_agg['tweets_delta'] = hashtags_agg['statuses_max'] - hashtags_agg['statuses_min']
hashtags_agg['followers_delta'] = hashtags_agg['followers_max'] - hashtags_agg['followers_min']
hashtags_agg['followees_delta'] = hashtags_agg['followees_max'] - hashtags_agg['followees_min']
hashtags_agg['tweet_intensity'] = (hashtags_agg['tweets']+1)/(hashtags_agg['tweets_delta']+1)
hashtags_agg['tweet_fraction'] = hashtags_agg['tweets']/hashtags_agg['statuses_min']

# Lowercase usernames for future joinabilitiy
hashtags_agg.index = hashtags_agg.reset_index()['user_screen_name'].apply(lambda x:x.lower())

# %%
nx.write_gexf(hashtags_g,'hashtags_graph.gexf')

# %% [markdown]
# # Analysis

# %%
tweet_counter = Counter(Counter(g_agg['tweets'].values).values())
plt.scatter(tweet_counter.keys(),tweet_counter.values())
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Number of tweets',fontsize=15)
plt.ylabel('Number of users',fontsize=15)

# %%
g_agg['tweet_intensity'].dropna().hist()
